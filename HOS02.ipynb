# %%
print("Hello")

# %% [markdown]
# # What is GitHub Copilot?
#
# GitHub Copilot is an AI-powered coding assistant that helps developers write, explain, and improve code.

# %% [markdown]
# # Best Practices for Using AI Assistants
#
# Use AI as a learning tool. Try solving problems first, then use AI to explain concepts, debug errors, and improve your understanding rather than completing all the work for you.
